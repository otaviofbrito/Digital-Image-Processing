# %%
import utils
import matplotlib.pyplot as plot
import matplotlib.image as image
import math
import numpy as np

img = utils.readpgm("./images/beans41.pgm")
plot.imshow(img.matrix, cmap='gray')
plot.axis('off') 
plot.show()
#76
# Out:
# 640 419
# 255

# %%
utils.threshold(img,100)
utils.distance(img)
utils.normalize(img, 255)
utils.threshold(img, 250)

utils.distance(img)
utils.normalize(img, 255)
utils.threshold(img, 240)

utils.cc_label(img)


plot.figure(figsize=(10, 10))
plot.imshow(img.matrix)
plot.axis('off')
# Out:
# 49
# (-0.5, 639.5, 418.5, -0.5)
